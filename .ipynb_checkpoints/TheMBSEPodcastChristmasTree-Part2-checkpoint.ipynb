# %%
  package TMPCT_PhysicalArchitecture {
           
    part theMBSEPodcastChristmasTree {
        
        part tree {
            part trunk;
            part branch[1..*];
            value height : ScalarValues::Integer;
            connect trunk to branch;
        }
          
        part transportationNet;
        connect transportationNet to tree;
           
        part christmasTreeStar;
        connect christmasTreeStar to tree;
            
        part christmasTreeStand;
        connect christmasTreeStand to tree::trunk;
            
        part fairyLights;
        connect fairyLights to tree::branch;
            
        part transportationPackage;
        connect transportationPackage to christmasTreeStar;
        connect transportationPackage to tree;
        connect transportationPackage to fairyLights;
        connect transportationPackage to powerManagementModule;
        connect transportationPackage to christmasTreeStand;
        connect transportationPackage to christmasBlanket;
            
        part ball[1..*] : ChristmasTreeBall;
        connect ball to tree::branch;
            
        part christmasBlanket;
        connect christmasBlanket to christmasTreeStand;
            
        part powerManagementModule;
        connect powerManagementModule to enjoymentControlUnit;
        connect powerManagementModule to fairyLights;
            
        part enjoymentControlUnit;
        connect enjoymentControlUnit to fairyLights;             
    }
     
    part def ChristmasTreeBall {
        enum def BallColor {
            enum red;
            enum blue;
            enum yellow;
         }
         value color : BallColor;
    }
}
# Out:
# Package TMPCT_PhysicalArchitecture (a720390e-f7e1-4437-a70d-82f87019b877)

# %%
%viz --view=interconnection TMPCT::TMPCT_PhysicalArchitecture

# %%
package ICS242526_12 {
    requirement def ReqTreeHeight {
        doc /* The tree shall be at least 150 cm and maximum 200 cm high. */

            attribute treeHeight : ScalarValues::Integer;
       
            require constraint{ 150 <= treeHeight <= 200 }
    }
}

import TMPCT_PhysicalArchitecture::*;

package TMPCT_Requirements {
        
    import ICS242526_12::*;

    requirement id 'REQ1' 'Height of the Tree' : ReqTreeHeight {
        attribute :>> treeHeight = theMBSEPodcastChristmasTree::tree::height;
    }
    
}
# Out:
# Package ICS242526_12 (5e1714f9-7aa6-412b-a232-b55124713579)
# Package TMPCT_Requirements (ac12c04c-1dbb-4def-9c2c-d3daec548f6c)

# %%
%viz --view=tree ICS242526_12

# %%
%viz --view=tree TMPCT_Requirements

# %%
 package TMPCT_PhysicalArchitecture {
           
    part theMBSEPodcastChristmasTree {
        
        part tree {
            part trunk;
            part branch[1..*];
            value height : ScalarValues::Integer;
            connect trunk to branch;
        }
          
        part transportationNet;
        connect transportationNet to tree;
           
        part christmasTreeStar;
        connect christmasTreeStar to tree;
            
        part christmasTreeStand;
        connect christmasTreeStand to tree::trunk;
            
        part fairyLights;
        connect fairyLights to tree::branch;
            
        part transportationPackage;
        connect transportationPackage to christmasTreeStar;
        connect transportationPackage to tree;
        connect transportationPackage to fairyLights;
        connect transportationPackage to powerManagementModule;
        connect transportationPackage to christmasTreeStand;
        connect transportationPackage to christmasBlanket;
            
        part ball[1..*] : ChristmasTreeBall;
        connect ball to tree::branch;
            
        part christmasBlanket;
        connect christmasBlanket to christmasTreeStand;
            
        part powerManagementModule;
        connect powerManagementModule to enjoymentControlUnit;
        connect powerManagementModule to fairyLights;
            
        part enjoymentControlUnit;
        connect enjoymentControlUnit to fairyLights;             
    }
     
    part def ChristmasTreeBall {
        enum def BallColor {
            enum red;
            enum blue;
            enum yellow;
         }
         value color : BallColor;
    }
}

package TMPCT_Variations {

    import TMPCT_PhysicalArchitecture::*;
    import TMPCT_Variants::*;
        
    abstract part christmasTreeVariations :> theMBSEPodcastChristmasTree {
        
       variation part redefines christmasTreeStar {
            variant part ecoStar;
            variant part premiumStar;  
            variant part standardStar;  
       }
       variation part redefines christmasTreeStand {
            variant part largeStand;
            variant part standardStand;
       }
      
       abstract constraint { (christmasTreeStar == premiumStar & christmasTreeStand == largeStand) }
   }
}   
    
package TMPCT_Variants {
        
    part ecoStar;
    part premiumStar {
        part ledLight;
    }
    part standardStar;

    part largeStand;
    part standardStand;
}
# Out:
# Package TMPCT_PhysicalArchitecture (8d31c361-a051-497b-91db-5dae8ddffc16)
# Package TMPCT_Variations (9120e3e3-8dd4-4635-86b7-633b9a63328c)
# Package TMPCT_Variants (f71af6c2-f758-4545-8c01-5ffd77f6efb4)

# %%
%viz TMPCT_Variations

# %%
package TMPCT_Configurations {
    
    import TMPCT_Variations::*;

    part ecoTree :> christmasTreeVariations {
        part redefines christmasTreeStar = ecoStar;
        part redefines christmasTreeStand = standardStand;
    }
    part premiumTree :> christmasTreeVariations {
        part redefines christmasTreeStar = premiumStar;
        part redefines christmasTreeStand = largeStand;
    }
}
# Out:
# Package TMPCT_Configurations (ff766aae-6af5-432b-b912-b6f87d1cc585)

# %%
%viz TMPCT_Configurations

# %%
package TMPCT {
    
package TMPCT_PhysicalArchitecture {
           
    part theMBSEPodcastChristmasTree {
        
        part tree {
            part trunk;
            part branch[1..*];
            value height : ScalarValues::Integer;
            connect trunk to branch;
        }
          
        part transportationNet;
        connect transportationNet to tree;
           
        part christmasTreeStar;
        connect christmasTreeStar to tree;
            
        part christmasTreeStand;
        connect christmasTreeStand to tree::trunk;
            
        part fairyLights;
        connect fairyLights to tree::branch;
            
        part transportationPackage;
        connect transportationPackage to christmasTreeStar;
        connect transportationPackage to tree;
        connect transportationPackage to fairyLights;
        connect transportationPackage to powerManagementModule;
        connect transportationPackage to christmasTreeStand;
        connect transportationPackage to christmasBlanket;
            
        part ball[1..*] : ChristmasTreeBall;
        connect ball to tree::branch;
            
        part christmasBlanket;
        connect christmasBlanket to christmasTreeStand;
            
        part powerManagementModule;
        connect powerManagementModule to enjoymentControlUnit;
        connect powerManagementModule to fairyLights;
            
        part enjoymentControlUnit;
        connect enjoymentControlUnit to fairyLights;             
    }
     
    part def ChristmasTreeBall {
        enum def BallColor {
            enum red;
            enum blue;
            enum yellow;
         }
         value color : BallColor;
    }
}

package TMPCT_Variations {

    import TMPCT_PhysicalArchitecture::*;
    import TMPCT_Variants::*;
        
    abstract part christmasTreeVariations :> theMBSEPodcastChristmasTree {
        
       variation part redefines christmasTreeStar {
            variant part ecoStar;
            variant part premiumStar;  
            variant part standardStar;  
       }
       variation part redefines christmasTreeStand {
            variant part largeStand;
            variant part standardStand;
       }
      
       abstract constraint { (christmasTreeStar == premiumStar & christmasTreeStand == largeStand) }
   }
}   
    
package TMPCT_Variants {
        
    part ecoStar;
    part premiumStar {
        part ledLight;
    }
    part standardStar;

    part largeStand;
    part standardStand;
}

package TMPCT_Configurations {
    
    import TMPCT_Variations::*;

    part ecoTree :> christmasTreeVariations {
        part redefines christmasTreeStar = ecoStar;
        part redefines christmasTreeStand = standardStand;
    }
    part premiumTree :> christmasTreeVariations {
        part redefines christmasTreeStar = premiumStar;
        part redefines christmasTreeStand = largeStand;
    }
}
    
package ICS242526_12 {
    requirement def ReqTreeHeight {
        doc /* The tree shall be at least 150 cm and maximum 200 cm high. */

            attribute treeHeight : ScalarValues::Integer;
       
            require constraint{ 150 <= treeHeight <= 200 }
    }
}

import TMPCT_PhysicalArchitecture::*;

package TMPCT_Requirements {
        
    import ICS242526_12::*;

    requirement id 'REQ1' 'Height of the Tree' : ReqTreeHeight {
        attribute :>> treeHeight = theMBSEPodcastChristmasTree::tree::height;
    }
    
}
}
# Out:
# Package TMPCT (b7b3add4-f3ea-49a2-a5b2-998ff31318b5)
