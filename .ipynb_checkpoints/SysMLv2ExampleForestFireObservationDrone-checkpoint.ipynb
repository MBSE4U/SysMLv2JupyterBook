# %% [markdown]
# # Experimental Model for a Forest Fire Observation Drone
#
# Copyright 2023 MBSE4U

# %%
package ForestFireObservationDrone {
    
    import Drone_SharedAssetsSuperset::**;
    
    part forestFireObservationDrone : Drone {
        
        // Power System
        :>> battery = battery::longDistanceBattery;
        
        part charger;
        part powerManagementModule {
            port ctrlPort {
                out attribute status : BatteryCapacityKind;
            }
            
            perform action checkStatus {
                out attribute status : BatteryCapacityKind;
                
                first start;
                then action getBatteryStatus;
                then action analyseStatus;
                then done;
            } 
        }

        // Flight Control System
        part droneControlUnit {
            port powerCtrlPort {
                in attribute batteryStatus : BatteryCapacityKind;
            }
        }
        part gpsModule;
        part inertialMeasurementUnit;
        part barometer;
        
        // Drone Frame
        part body;
        part rotors[4];
        part arms[4];
        part landingGear;
        
        // Communication System
        part radioTransmitter;
        part radioReceiver;
        part antenna;
        
        // Sensors
        part camera;
        part obstacleAvoidanceSensor;
        
        // Engine
        part engine1 : DroneEngine {
            :>> propKind = PropKind::clockwise;
        }
        part engine2 : DroneEngine {
            :>> propKind = PropKind::counterclockwise;
        }
        part engine3 : DroneEngine {
            :>> propKind = PropKind::clockwise;
        }        
        part engine4 : DroneEngine {
            :>> propKind = PropKind::counterclockwise;
        }
        
        // Connections
        connect droneControlUnit.powerCtrlPort to powerManagementModule.ctrlPort;
        connect battery to powerManagementModule;
        connect powerManagementModule to engine1;
        connect powerManagementModule to engine2;
        connect powerManagementModule to engine3;
        connect powerManagementModule to engine4;                    
    }
}
# Out:
# Package ForestFireObservationDrone (6b4f44e0-84ed-4942-9d50-7ab213ec6647)

# %%
%viz ForestFireObservationDrone

# %% [markdown]
# # Feature Model

# %%
package Drone_FeatureModel {
    requirement drone {    
        variation requirement numberOfEngines {
            variant requirement fourEngines;
            variant requirement sixEngines {
                require batteryKind::longDistanceBattery;
            }
        }
        
        variation requirement batteryKind {
            variant requirement standardBattery;
            variant requirement longDistanceBattery;
        }
    } 
}
# Out:
# Package Drone_FeatureModel (1ee91e23-7d35-4bff-9f2f-8caad97b4d59)

# %% [markdown]
# # Shared Asset Superset
#
# The shared asset superset contains all shared assets of the drone product line. The forest fire observation drone is one product of the product line. Other member products could be a camera drone, a surveillance drone, and so forth.

# %%
library package Drone_SharedAssetsSuperset {
    
    package DroneProductLine {
        
        import DroneBattery::**;
        import DroneEngine::*;
               
        abstract part def Drone {          
            // Power
            part battery :> droneBatteryVariation;
            
            // Engines
            variation attribute numberOfEngines : ScalarValues::Integer {
                variant attribute fourEngines = 4;
                variant attribute sixEngines = 6;
            }
            assert constraint { 
                (numberOfEngines == numberOfEngines::sixEngines) and 
                (battery == DroneBattery_Variation::droneBatteryVariation::longDistanceBattery) 
            }
            satisfy Drone_FeatureModel::drone.numberOfEngines by numberOfEngines;                
            part engine[4..numberOfEngines] : DroneEngine;
        }
        
        use case observeArea {
            subject drone : Drone;
            
            first start;
            then action defineObservationArea {
                in hi_observationArea;
                out observationArea;
            }
            then done;
        }
    }
     
    package DroneEngine {
        
        part def DroneEngine {
            enum propKind : PropKind;
            
            enum def PropKind {
                enum clockwise;
                enum counterclockwise;
            }            
        }
                
        package DroneEngine_StakeholderRequirements {
                    
            variation requirement droneEngineStakeholderRequirements {
                variant requirement droneEngineStandardStakeholderRequirements {
                    
                    subject engine : DroneEngine;
                                        
                    requirement power : Power;
                    requirement efficiency : Efficiency;
                    requirement durability : Durability;
                    requirement reliability : Reliability;
                    requirement lightweight : Lightweight;
                    requirement control : Control;
                    requirement compatibility : Compatibility;
                    requirement safety : Safety;
                    requirement costEffective : CostEffective;
                }
                variant requirement droneEngineLowNoiseStakeholderRequirements :> droneEngineStandardStakeholderRequirements {
                    requirement lowNoise : LowNoise;
                }
            }
            
            requirement def <'DE-REQ-1'> Power {
                doc /*
                    * The engine should provide enough power to lift the drone off the ground and keep it in the air. 
                    * The power output should be appropriate for the size and weight of the drone.
                    */
            }
            requirement def <'DE-REQ-2'> Efficiency {
                doc /*
                    * The engine should be efficient, allowing the drone to fly for an extended period on a single charge. 
                    * The engine should be designed to minimize energy loss through friction and heat.
                    */
            }
            requirement def <'DE-REQ-3'> Durability {
                doc /*
                    * The engine should be able to withstand the stress of continuous use and exposure to the elements. 
                    * It should be able to operate in a wide range of temperatures and weather conditions.
                    */
            }
            requirement def <'DE-REQ-4'> Reliability {
                doc /*
                    * The engine should be reliable, with minimal downtime or maintenance requirements. 
                    * It should be designed with high-quality components and undergo rigorous testing before deployment.
                    */
            }
            requirement def <'DE-REQ-5'> LowNoise {
                doc /*
                    * The engine should produce minimal noise to avoid disturbing the environment or attracting unwanted attention.
                    */
            }
            requirement def <'DE-REQ-6'> Lightweight {
                doc /*
                    * The engine should be lightweight, allowing for maximum payload capacity and longer flight times.
                    */
            }
            requirement def <'DE-REQ-7'> Control {
                doc /*
                    * The engine should be easy to control, allowing for precise maneuverability and responsiveness to commands.
                    */
            }
            requirement def <'DE-REQ-8'> Compatibility {
                doc /*
                    * The engine should be compatible with the drone's power supply and electronic components.
                    */
            }
            requirement def <'DE-REQ-9'> Safety {
                doc /*
                    * The engine should be designed with safety in mind, minimizing the risk of injury or damage in case of malfunction. 
                    * It should have fail-safe mechanisms to prevent accidents and minimize damage in case of emergency.
                    */
            }
            requirement def <'DE-REQ-10'> CostEffective {
                doc /*
                    * The engine should be cost-effective, balancing performance and quality with affordability. 
                    * It should provide value for money, with a low cost of ownership and maintenance.            
                    */
            }            
        }
    }
    
    package DroneBody {
        
    }
    
    package DroneFlightControlSoftware {
        
    }
    
    package DroneBattery {
        
        package DroneBattery_Variation {
        
            import DroneBattery_Parts::*;
            import DroneBattery_SystemRequirements::*;
            
            variation part droneBatteryVariation : DroneBattery {
                variant part standardBattery : StandardDroneBattery;
                variant part longDistanceBattery : LongDistanceDroneBattery {
                    satisfy droneBatterySystemRequirements.droneBatteryLongDistanceSystemRequirements by self;
                }
            }
            satisfy Drone_FeatureModel::drone.batteryKind by droneBatteryVariation;
        }
        
        package DroneBattery_Parts {
                        
            abstract part def DroneBattery {
                // Attributes
                attribute weight : ISQBase::MassValue; 
                attribute maxCapacity : ISQElectromagnetism::ElectricChargeValue;
                enum currentCapacityLevel : BatteryCapacityKind;
                enum def BatteryCapacityKind :> ScalarValues::Integer {
                    enum full = 100;
                    enum medium = 50;
                    enum low = 30;
                    enum critical = 15;
                }
            
                // Parts
                part batteryCells {
                    doc /* The battery cells are the main components of the drone battery 
                         * that store the electrical energy. These cells are usually Lithium Polymer (LiPo) 
                         * or Lithium-Ion (Li-Ion) cells.
                        */
                }
                part batteryManagementSystem {
                    doc /* The Battery Management System (BMS) is a control unit that manages the charging and 
                         * discharging of the battery cells. It ensures that the cells are charged and discharged 
                         * correctly and safely.
                         */
                }
                part protectionCircuit {
                    doc /* The protection circuit is a safety mechanism that protects the battery from overcharging, 
                         * over-discharging, and short circuits.
                        */
                }
                part powerConnector {
                    doc /* The power connector is the interface that connects the battery to the drone's power system. 
                        * It delivers the electrical energy from the battery to the drone.
                        */
                }
                part chargingInterface {
                    doc /* The charging interface is the interface that connects the battery to the charger. 
                         * It allows the battery to be charged safely and efficiently.
                        */
                }
                part batteryIndicator {
                    doc /* The battery indicator is a component that displays the remaining battery charge. 
                         * It allows the pilot to monitor the battery level and plan flight time accordingly.
                        */
                }
                part communicationInterface {
                    doc /* The communication interface is a component that allows the battery to communicate 
                         * with the drone's flight controller. It provides important battery information such 
                         * as voltage, current, and temperature to the flight controller.
                        */
                    }
                part firmware {
                    doc /* The firmware is the software that runs on the battery management system. 
                         * It controls the charging and discharging of the battery cells and ensures 
                         * that the battery operates safely and efficiently.
                        */
                }
            }
                             
            part def StandardDroneBattery :> DroneBattery {
                :>> weight = 275[SI::g];
                :>> maxCapacity = 13680[SI::'s⋅A'];
            }
            part def LongDistanceDroneBattery :> DroneBattery {
                :>> weight = 315[SI::g];
                :>> maxCapacity = 18000[SI::'s⋅A'];
            }
        }
            
        package DroneBattery_SystemRequirements {
            
            import RequirementDerivation::*;
            import DroneBattery_StakeholderRequirements::*;
            import DroneBattery_Parts::*;
            
            variation requirement droneBatterySystemRequirements {
                variant requirement droneBatteryStandardSystemRequirements {
                    satisfy Drone_FeatureModel::drone.batteryKind.standardBattery by self;
                    subject battery : DroneBattery;    
                }
                variant requirement droneBatteryLongDistanceSystemRequirements {
                    satisfy Drone_FeatureModel::drone.batteryKind.longDistanceBattery by self;
                    subject battery : DroneBattery;
                    
                    requirement longDistanceCapacity : LongDistanceCapacity;
                    #derivation connection {
                        end #original ::> droneBatteryStakeholderRequirements.highCapacity;
                        end #derive ::> longDistanceCapacity;
                    }
                }                                               
            }
            satisfy Drone_FeatureModel::drone.batteryKind by droneBatterySystemRequirements;
            
            requirement def <'DB-REQ-421'> LongDistanceCapacity {
                doc /* The battery has a high capacity of 3850mAh, which provides enough power for extended flight times. */
                    
                subject battery : DroneBattery;
                
                assert constraint {
                    (battery.maxCapacity >= 18000[SI::'s⋅A'])
                }
            }
        }
        
        package DroneBattery_StakeholderRequirements {
            
            import DroneBattery_Parts::*;
            
            requirement droneBatteryStakeholderRequirements {
                
                subject battery : DroneBattery;
                
                requirement lightweight : Lightweight;
                requirement highCapacity : HighCapacity;
                requirement fastCharging : FastCharging;
                requirement longLife : LongLife;
                requirement safe : Safe;
                requirement compatible : Compatible;
                requirement reliable : Reliable;
                requirement affordable : Affordable;
                requirement easyToInstall : EasyToInstall;
            }
            
            requirement def <'DB-REQ-2'> Lightweight {
                doc /*
                     * A drone battery should be lightweight to keep the overall weight of the drone 
                     * to a minimum, which is essential for stable flight.
                    */
            }

            requirement def <'DB-REQ-3'> HighCapacity {
                doc /*
                     * A drone battery should have a high capacity to provide the drone with enough power 
                     * to fly for a reasonable amount of time.
                    */
            }

            requirement def <'DB-REQ-4'> FastCharging {
                doc /*
                     * A drone battery should be able to charge quickly so that the drone can 
                     * get back in the air as soon as possible.
                    */
            }

            requirement def <'DB-REQ-5'> LongLife {
                doc /*
                     * A drone battery should have a long life to avoid the need for frequent replacements.
                    */
            }

            requirement def <'DB-REQ-6'> Safe {
                doc /*
                     * A drone battery should be designed to be safe, with features such as overcharge protection, 
                     * short circuit protection, and temperature control.
                    */
            }

            requirement def <'DB-REQ-7'> Compatible {
                doc /*
                     * A drone battery should be compatible with the drone's power system to ensure proper functioning.
                    */
            }
            
            requirement def <'DB-REQ-8'> Reliable {
                doc /*
                     * A drone battery should be reliable, with consistent performance and the ability to withstand 
                     * the stresses of flight and charging cycles.
                    */
            }

            requirement def <'DB-REQ-9'> Affordable {
                doc /*
                     * A drone battery should be reasonably priced, to avoid being a significant expense for drone pilots.
                    */
            }
            
            requirement def <'DB-REQ-10'> EasyToInstall {
                doc /*
                     * A drone battery should be easy to install and remove to make it easy for pilots to swap out batteries when necessary.
                    */
            }
        }
    }    
}

package Drone_FeatureModel {
    
    import PLEML::*;
    
    #feature drone {    
        #mandatoryFeature numberOfEngines {
            #feature fourEngines;
            #feature requirement sixEngines {
                require batteryKind.longDistanceBattery;
            }
        }
        
        #mandatoryFeature batteryKind {
            #feature standardBattery;
            #feature longDistanceBattery;
        }
    } 

    #featureConfiguration requirement forestFireObservationDrone {
        require drone.numberOfEngines.sixEngines;
        require drone.batteryKind.longDistanceBattery;
    }
    
    view DroneFeatureTree {
        expose drone::**;
        render Views::asTreeDiagram;
    }
}
# Out:
# ERROR:Couldn't resolve reference to Namespace 'PLEML'. (1.sysml line : 335 column : 12)
# ERROR:Couldn't resolve reference to Type 'feature'. (1.sysml line : 337 column : 6)
# ERROR:Couldn't resolve reference to Type 'mandatoryFeature'. (1.sysml line : 345 column : 10)
# ERROR:Couldn't resolve reference to Type 'feature'. (1.sysml line : 346 column : 14)
# ERROR:Couldn't resolve reference to Type 'feature'. (1.sysml line : 347 column : 14)
# ERROR:Couldn't resolve reference to Type 'mandatoryFeature'. (1.sysml line : 338 column : 10)
# ERROR:Couldn't resolve reference to Type 'feature'. (1.sysml line : 339 column : 14)
# ERROR:Couldn't resolve reference to Type 'feature'. (1.sysml line : 340 column : 14)
# ERROR:Couldn't resolve reference to Type 'featureConfiguration'. (1.sysml line : 351 column : 6)
# ERROR:A metadata usage must be typed by one metadata definition. (1.sysml line : 337 column : 6)
# ERROR:Must have a concrete type (1.sysml line : 337 column : 6)
# ERROR:A metadata usage must be typed by one metadata definition. (1.sysml line : 338 column : 10)
# ERROR:Must have a concrete type (1.sysml line : 338 column : 10)
# ERROR:A metadata usage must be typed by one metadata definition. (1.sysml line : 339 column : 14)
# ERROR:Must have a concrete type (1.sysml line : 339 column : 14)
# ERROR:A metadata usage must be typed by one metadata definition. (1.sysml line : 340 column : 14)
# ERROR:Must have a concrete type (1.sysml line : 340 column : 14)
# ERROR:A metadata usage must be typed by one metadata definition. (1.sysml line : 345 column : 10)
# ERROR:Must have a concrete type (1.sysml line : 345 column : 10)
# ERROR:A metadata usage must be typed by one metadata definition. (1.sysml line : 346 column : 14)
# ERROR:Must have a concrete type (1.sysml line : 346 column : 14)
# ERROR:A metadata usage must be typed by one metadata definition. (1.sysml line : 347 column : 14)
# ERROR:Must have a concrete type (1.sysml line : 347 column : 14)
# ERROR:A metadata usage must be typed by one metadata definition. (1.sysml line : 351 column : 6)
# ERROR:Must have a concrete type (1.sysml line : 351 column : 6)

# %%
%viz Drone_FeatureModel::DroneFeatureTree

# %%
%show Drone_SharedAssetsSuperset::DroneProductLine::Drone
# Out:
# PartDefinition Drone (1952cdb5-1cb9-421e-8d14-9e0a0f589646)
#   [Subclassification (implicit)] PartDefinition Part (71ca925d-ad00-40a8-b36e-a20f989ae60b)
#   [FeatureMembership] PartUsage battery (b79b16d3-12bc-47dd-8c6f-8c3c8cbde227)
#     [Subsetting (implicit)] PartUsage subparts (853bfa29-73bf-428a-b954-78b319b74985)
#     [Subsetting] PartUsage droneBatteryVariation (6511fc06-05e1-4caa-b12a-584a8211afa6)
#     [OwningMembership] Multiplicity (ba1229c6-8481-4380-8c6f-bc3049b7510c)
#       [Subsetting (implicit)] MultiplicityRange exactlyOne (87fe6382-70f8-46b7-b12f-60080f7020d3)
#   [FeatureMembership] AttributeUsage numberOfEngines (06b64956-0209-4dc5-93bb-047e96df4ea5)
#     [Subsetting (implicit)] Feature dataValues (69084ab8-f9f7-4c13-8ffb-5874c5c6129a)
#     [FeatureTyping] DataType Integer (19d88df5-ec1b-4f3f-a9a9-aacbd26344e2)
#     [VariantMembership] AttributeUsage fourEngines (215f080b-d12b-4791-ba3e-af297aa25fcd)
#       [Subsetting (implicit)] AttributeUsage numberOfEngines (06b64956-0209-4dc5-93bb-047e96df4ea5)
#       [Subsetting (implicit)] Feature result (79d98356-287f-42ee-b621-e99de2257aac)
#       [FeatureValue] LiteralInteger 4 (ee1a3d82-8f27-49da-9d58-bdfb2925a361)
#         [ReturnParameterMembership] Feature result (79d98356-287f-42ee-b621-e99de2257aac)
#     [VariantMembership] AttributeUsage sixEngines (7459ee3c-8e94-4c65-91fa-9c14b051e9d3)
#       [Subsetting (implicit)] AttributeUsage numberOfEngines (06b64956-0209-4dc5-93bb-047e96df4ea5)
#       [Subsetting (implicit)] Feature result (c1800e50-fb7a-4a4a-9946-b90d7997893e)
#       [FeatureValue] LiteralInteger 6 (744895c4-f931-4917-9035-aa915bba17a9)
#         [ReturnParameterMembership] Feature result (c1800e50-fb7a-4a4a-9946-b90d7997893e)
#     [OwningMembership] Multiplicity (d91739ac-683f-4e22-8d35-c3a5882b8654)
#       [Subsetting (implicit)] MultiplicityRange exactlyOne (87fe6382-70f8-46b7-b12f-60080f7020d3)
#   [FeatureMembership] SatisfyRequirementUsage (f12ec5e2-e174-4529-98ae-bdb623242eb4)
#     [ReturnParameterMembership] ReferenceUsage result (9e1370bb-6f07-4817-af28-37a3b2a7f8ee)
#   [FeatureMembership] PartUsage engine (582c7598-f98b-427c-8906-1c038f23ee56)
#     [Subsetting (implicit)] PartUsage subparts (853bfa29-73bf-428a-b954-78b319b74985)
#     [OwningMembership] MultiplicityRange (bdfb302b-fd2d-4f52-b714-9d2ef28fc179)
#       [Subsetting (implicit)] Feature naturals (c13e0fab-1e46-4bd6-bd0e-e2ce41bd54b3)
#       [OwningMembership] LiteralInteger 4 (eca41f6d-a4f1-4c84-8ecb-f921c71caa4e)
#         [ReturnParameterMembership] Feature result (3f1b242e-f90b-49e3-93b7-0fe11eb743fd)
#       [OwningMembership] FeatureReferenceExpression numberOfEngines (4d957859-7d31-4eb4-8007-af6537d601e5)
#         [ReturnParameterMembership] Feature result (5c82fe16-c472-41ef-8d0d-0395baaf3117)
#     [FeatureTyping] PartDefinition DroneEngine (e2c10a28-684c-476e-aa48-8019eb038122)

# %%
%publish Drone_FeatureModel
# Out:
# API base path: http://sysml2.intercax.com:9000
# Processing...
# Posting Commit (344 elements)...983f5944-3844-4ca5-b1b0-5ca4835f896f
# Saved to Project Drone_FeatureModel Sat Apr 01 15:59:00 CEST 2023 (9083ade4-b0be-4f80-a549-ee628138df70)

# %%
%show Drone_FeatureModel
# Out:
# Package Drone_FeatureModel (d1a3fd3b-a471-4ad6-99f4-3460e5ecf16a)
#   [NamespaceImport] LibraryPackage PLEML (7f1aecce-7f46-4638-98a8-693d5b7d6263)
#   [OwningMembership] Usage drone (194c859e-3055-445f-a285-6595870da8a0)
#     [Subsetting (implicit)] RequirementUsage features (7de612d0-364b-47cc-8bdf-5386858d979c)
#     [OwningMembership] MetadataUsage (1e5359be-68ef-4ba3-aefb-b16efae69add)
#       [Subsetting (implicit)] ItemUsage metadataItems (86602516-5280-4899-8e5f-4a1f4e6e99aa)
#       [FeatureTyping] MetadataDefinition <feature> FeatureDSM (d9726a11-3f32-44c3-bbc9-a42895268533)
#     [FeatureMembership] Usage numberOfEngines (1d777490-f258-44f1-8525-080a7d8a0abb)
#       [Subsetting (implicit)] RequirementUsage mandatoryFeatures (8426183e-f576-459a-a419-e41a76ffed41)
#       [OwningMembership] MetadataUsage (efa04cd6-f48b-434d-956a-372d5b7b8a58)
#         [Subsetting (implicit)] ItemUsage metadataItems (86602516-5280-4899-8e5f-4a1f4e6e99aa)
#         [FeatureTyping] MetadataDefinition <mandatoryFeature> MandatoryFeatureDSM (8032bad9-94d4-48bc-8523-c5547025eda7)
#       [FeatureMembership] Usage fourEngines (b3dcb010-c2ff-4c4f-b708-71c301bb5373)
#         [Subsetting (implicit)] RequirementUsage alternativeFeatures (e7614c27-5c49-44be-8b0e-d9bc90ba0966)
#         [OwningMembership] MetadataUsage (246b15db-7716-4ca7-94a3-5d8e072b9aed)
#           [Subsetting (implicit)] ItemUsage metadataItems (86602516-5280-4899-8e5f-4a1f4e6e99aa)
#           [FeatureTyping] MetadataDefinition <altFeature> AlternativeFeatureDSM (0950947e-0fe6-4bf6-b10b-f38959b7dfed)
#       [FeatureMembership] Usage sixEngines (d454d044-8862-4742-a377-1b5d57616a70)
#         [Subsetting (implicit)] RequirementUsage alternativeFeatures (e7614c27-5c49-44be-8b0e-d9bc90ba0966)
#         [OwningMembership] MetadataUsage (8d3f2cf0-b649-43df-bcc9-315fb2600783)
#           [Subsetting (implicit)] ItemUsage metadataItems (86602516-5280-4899-8e5f-4a1f4e6e99aa)
#           [FeatureTyping] MetadataDefinition <altFeature> AlternativeFeatureDSM (0950947e-0fe6-4bf6-b10b-f38959b7dfed)
#     [FeatureMembership] Usage batteryKind (4e4b4cbb-36f6-4a88-a848-8d9ed17ac9c8)
#       [Subsetting (implicit)] RequirementUsage mandatoryFeatures (8426183e-f576-459a-a419-e41a76ffed41)
#       [OwningMembership] MetadataUsage (bc48c927-b864-4642-b949-0cd05c92f77e)
#         [Subsetting (implicit)] ItemUsage metadataItems (86602516-5280-4899-8e5f-4a1f4e6e99aa)
#         [FeatureTyping] MetadataDefinition <mandatoryFeature> MandatoryFeatureDSM (8032bad9-94d4-48bc-8523-c5547025eda7)
#       [FeatureMembership] Usage standardBattery (1c56d653-4063-4e7b-8ff8-bc883de759e9)
#         [Subsetting (implicit)] RequirementUsage alternativeFeatures (e7614c27-5c49-44be-8b0e-d9bc90ba0966)
#         [OwningMembership] MetadataUsage (aff09134-b006-48c5-914b-4bb734f4dfa1)
#           [Subsetting (implicit)] ItemUsage metadataItems (86602516-5280-4899-8e5f-4a1f4e6e99aa)
#           [FeatureTyping] MetadataDefinition <altFeature> AlternativeFeatureDSM (0950947e-0fe6-4bf6-b10b-f38959b7dfed)
#       [FeatureMembership] Usage longDistanceBattery (20248f78-d101-400a-82b1-8a0d166ff027)
#         [Subsetting (implicit)] RequirementUsage alternativeFeatures (e7614c27-5c49-44be-8b0e-d9bc90ba0966)
#         [OwningMembership] MetadataUsage (5cceb1a5-1333-4d60-8dc8-993dc5ce48f3)
#           [Subsetting (implicit)] ItemUsage metadataItems (86602516-5280-4899-8e5f-4a1f4e6e99aa)
#           [FeatureTyping] MetadataDefinition <altFeature> AlternativeFeatureDSM (0950947e-0fe6-4bf6-b10b-f38959b7dfed)
#   [OwningMembership] RequirementUsage forestFireObservationDrone (6fa5c1ff-1a16-4f18-8c6d-af96b58c2a52)
#     [ReturnParameterMembership] ReferenceUsage result (036b501f-a165-4437-8379-6c5374e8b185)
#   [OwningMembership] ViewUsage DroneFeatureTree (61cecfab-a65d-4fde-ba68-f1b035d5910b)
#     [Subsetting (implicit)] ViewUsage views (7e11cd55-1cd3-4ce6-83af-ee93841701cf)
#     [MembershipExpose] OwningMembership (f75ceb2d-cbae-41e6-877e-d7cc7ac9cac9)
#     [ViewRenderingMembership] RenderingUsage asTreeDiagram (fcba2313-d041-437e-9d55-ee969ceaf464)
#       [Redefinition (implicit)] RenderingUsage viewRendering (4c8e6efd-978b-48a1-a13f-2b37d7855159)
#       [ReferenceSubsetting] RenderingUsage asTreeDiagram (9d0caff5-8770-4f18-9c64-0a75d09d3e79)
#       [OwningMembership] Multiplicity (9e9e36fc-5a87-42f0-8448-6b196ce279d0)
#         [Subsetting (implicit)] MultiplicityRange exactlyOne (99c82737-c592-45b5-9618-584cffeeadf7)

# %% [markdown]
# # SysML extension for MBPLE
#
# The MBPLE extension Product Line Engineering Modeling Language (PLEML) provides concepts for modeling features with SysML v2.

# %%
library package PLEML {
    doc /* 
        *  Product Line Engineering Modeling Language - Language extension for SysML v2 
        */
        
    // Concepts
    requirement def Feature {
        attribute isMandatory : ScalarValues::Boolean = false;
        attribute bindingTime : BindingTimeKind = BindingTimeKind::Design;
        enum def BindingTimeKind {
            enum Design;
            enum Production;
            enum Operation;
        }
        ref requirement subFeatures[0..*] : Feature;
        ref requirement alternativeFeatures[*] :> subFeatures;
    }
    requirement features[*] : Feature;

    requirement mandatoryFeatures[*] :> features {
        :>> isMandatory = true;
        assert constraint { isMandatory == true }
    }
    
    requirement def FeatureConfiguration :> Feature {
        assert constraint {
            CollectionFunctions::size(alternativeFeatures->ControlFunctions::select { in f : Feature; f.isMandatory == true }) == 1
        }        
    }
    requirement featureConfigurations[*] : FeatureConfiguration;
    
    // Domain-specific Metadata
    metadata def <feature> FeatureDSM :> Metaobjects::SemanticMetadata {
        :>> baseType = features meta SysML::Usage;
    }
    metadata def <mandatoryFeature> MandatoryFeatureDSM :> Metaobjects::SemanticMetadata {
        :>> baseType = mandatoryFeatures meta SysML::Usage;
    }    
    metadata def <featureConfiguration> FeatureConfigurationDSM :> Metaobjects::SemanticMetadata {
        :>> baseType = featureConfigurations meta SysML::Usage;
    }    
}
# Out:
# LibraryPackage PLEML (c778855d-5320-4457-9ede-6082daec67ee)

# %%
  
    #specialRE myRE;
    requirement otherRE;
    #specification requirement mySpec {
        require myRE;
    }

    requirement def SpecialRequirement;
    requirement specialRequirements[*] : SpecialRequirement;
    
    requirement def Specification;
    requirement specifications[*] : Specification;
    
    metadata def <specification> SpecificationDSM :> Metaobjects::SemanticMetadata {
        :>> baseType = specifications meta SysML::RequirementUsage;
    }
    metadata def <specialRE> SpecialREDSM :> Metaobjects::SemanticMetadata {
        :>> baseType = specialRequirements meta SysML::RequirementUsage;
    }
# Out:
# Usage myRE (c22be7c5-81c5-4c2a-9fcd-bc6dd73d14aa)
# RequirementUsage otherRE (0b7c7ef9-8638-4162-a7a6-ae585b0173c2)
# RequirementUsage mySpec (af311be3-b191-413d-8dbe-3e11fe78284a)
# RequirementDefinition SpecialRequirement (deec7704-eba7-47e6-abe4-ed9ff4ee070a)
# RequirementUsage specialRequirements (9b493c93-8d5c-4be7-b5cb-52eaf80a504d)
# RequirementDefinition Specification (5eeb4356-465d-4af1-b84e-ac190ffc157e)
# RequirementUsage specifications (abb83bf0-7e10-4ab0-b38d-b41a9261606f)
# MetadataDefinition <specification> SpecificationDSM (023c3258-d30b-447c-b026-ea115b5cbc2f)
# MetadataDefinition <specialRE> SpecialREDSM (77d9b878-2665-403b-9e72-cf63e64d0ebf)

# %%
%show RETest
# Out:
# Package RETest (b071f476-9643-474a-b19a-9a5ac9910dea)
#   [NamespaceImport] Package REExtension (d720ad01-78b2-4fa9-9c44-9f192e0b702f)
#   [OwningMembership] Usage myRE (2bf24357-93af-4bf2-9217-f24ee29e4fe5)
#     [Subsetting (implicit)] RequirementUsage specialRequirements (4236f16a-7b5c-4ad0-95c2-8c0dd518a6fa)
#     [OwningMembership] MetadataUsage (ebd16405-a5ab-4770-869e-fdaea6fdc45d)
#       [Subsetting (implicit)] ItemUsage metadataItems (86602516-5280-4899-8e5f-4a1f4e6e99aa)
#       [FeatureTyping] MetadataDefinition <specialRE> SpecialREDSM (b86fa547-1e2f-4cf0-8fa9-fc74c92b0f1c)
#   [OwningMembership] RequirementUsage otherRE (3fbc6824-4be0-4d94-98b9-2aa0c85c74b1)
#     [ReturnParameterMembership] ReferenceUsage result (431c1066-d18c-46b8-ab66-627bc1fa2eee)
#   [OwningMembership] Usage mySpec (23d00b21-ac85-4071-a43c-35d6e216269a)
#     [Subsetting (implicit)] RequirementUsage specifications (a47eedba-0168-495b-8f78-6dca1dbbed59)
#     [OwningMembership] MetadataUsage (52f82f74-30cd-47f3-a692-327fffb8f7be)
#       [Subsetting (implicit)] ItemUsage metadataItems (86602516-5280-4899-8e5f-4a1f4e6e99aa)
#       [FeatureTyping] MetadataDefinition <specification> SpecificationDSM (701d22ce-8e84-4764-9ddc-d6382b793da8)
#     [FeatureMembership] Usage myRE (0ba8eccc-211e-4c38-99f3-a72797bfd670)
#       [Subsetting (implicit)] RequirementUsage specialRequirements (4236f16a-7b5c-4ad0-95c2-8c0dd518a6fa)
#       [OwningMembership] MetadataUsage (d6c29e2f-3477-44e4-8bcb-3fd5f298189c)
#         [Subsetting (implicit)] ItemUsage metadataItems (86602516-5280-4899-8e5f-4a1f4e6e99aa)
#         [FeatureTyping] MetadataDefinition <specialRE> SpecialREDSM (b86fa547-1e2f-4cf0-8fa9-fc74c92b0f1c)

# %%
%export a
# Out:
# <p><a download="a.json" href="data:application/json;base64,...">Download</a>
